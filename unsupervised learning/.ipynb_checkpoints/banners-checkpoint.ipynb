# %%
import pandas as pd
import numpy as np
from sklearn.cluster import MeanShift

# %%
data = pd.read_csv('checkins.dat', sep='|', skipinitialspace=True, skiprows=[1])
data = data.dropna()
data.rename({'latitude      ': 'latitude', 'longitude     ': 'longitude'})
data = data.iloc[:100000, :].loc[:, ['latitude', 'longitude']]

data
# Out:
# C:\Everything\IT Programs\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#           id       user_id   venue_id   latitude        longitude       \
# 1         984222    15824.0     5222.0       38.895112      -77.036366
# 3         984234    44652.0     5222.0       33.800745      -84.410520
# 7         984291   105054.0     5222.0       45.523452     -122.676207
# 9         984318  2146539.0     5222.0       40.764462     -111.904565
# 10        984232    93870.0   380645.0       33.448377     -112.074037
# ...          ...        ...        ...             ...             ...
# 1021959  955561    626076.0    20073.0       40.850100      -73.866246
# 1021960  955892    674797.0     2297.0       33.748995      -84.387982
# 1021961  956377    845102.0    11195.0       42.765366      -71.467566
# 1021962  956119   1139114.0    29488.0       42.439479      -83.743830
# 1021964  956733    960666.0       60.0       42.331427      -83.045754
#
#             created_at
# 1        2012-04-21 17:43:47
# 3        2012-04-21 17:43:43
# 7        2012-04-21 17:39:22
# 9        2012-04-21 17:35:46
# 10       2012-04-21 17:38:18
# ...                      ...
# 1021959  2012-04-13 09:56:48
# 1021960  2012-04-13 10:56:03
# 1021961  2012-04-13 12:08:45
# 1021962  2012-04-13 11:36:44
# 1021964  2012-04-13 21:56:19
#
# [396634 rows x 6 columns]

# %%
data.columns
# Out:
# Index(['id    ', 'user_id ', 'venue_id ', 'latitude      ', 'longitude     ',
#        'created_at      '],
#       dtype='object')

# %%
data = data.iloc[:100000, :].loc[:, ['latitude      ', 'longitude     ']]
data
# Out:
#         latitude        longitude
# 1            38.895112      -77.036366
# 3            33.800745      -84.410520
# 7            45.523452     -122.676207
# 9            40.764462     -111.904565
# 10           33.448377     -112.074037
# ...                ...             ...
# 233788       33.575000     -117.725556
# 233789       37.629349     -122.400087
# 233793       29.762884      -95.383061
# 233797       32.802955      -96.769923
# 233798       37.774929     -122.419415
#
# [100000 rows x 2 columns]

# %%
# Out:
#         latitude        longitude
# 1            38.895112      -77.036366
# 3            33.800745      -84.410520
# 7            45.523452     -122.676207
# 9            40.764462     -111.904565
# 10           33.448377     -112.074037
# ...                ...             ...
# 233788       33.575000     -117.725556
# 233789       37.629349     -122.400087
# 233793       29.762884      -95.383061
# 233797       32.802955      -96.769923
# 233798       37.774929     -122.419415
#
# [100000 rows x 2 columns]

# %%
ms = MeanShift(bandwidth=0.1)
ms.fit(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7972/3756431639.py in <module>
#       1 ms = MeanShift(bandwidth=0.1)
# ----> 2 ms.fit(data)
#
# C:\Everything\IT Programs\anaconda3\lib\site-packages\sklearn\cluster\_mean_shift.py in fit(self, X, y)
#     375
#     376         """
# --> 377         X = self._validate_data(X)
#     378         bandwidth = self.bandwidth
#     379         if bandwidth is None:
#
# C:\Everything\IT Programs\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# C:\Everything\IT Programs\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# C:\Everything\IT Programs\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     671                     array = array.astype(dtype, casting="unsafe", copy=False)
#     672                 else:
# --> 673                     array = np.asarray(array, order=order, dtype=dtype)
#     674             except ComplexWarning as complex_warning:
#     675                 raise ValueError("Complex data not supported\n"
#
# C:\Everything\IT Programs\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# C:\Everything\IT Programs\anaconda3\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    1991
#    1992     def __array__(self, dtype: NpDtype | None = None) -> np.ndarray:
# -> 1993         return np.asarray(self._values, dtype=dtype)
#    1994
#    1995     def __array_wrap__(
#
# C:\Everything\IT Programs\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: could not convert string to float: '2012-04-21 17:43:47'
